# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
cols = cols = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
df = pd.read_csv('D:\programing\Introduction to Data Analytics\My Test\imports-85.data.txt', names=cols)
print(df.shape)
df.sample(5)
# Out:
# (205, 26)
#      symboling normalized-losses        make  ... city-mpg highway-mpg  price
# 193          0                 ?  volkswagen  ...       25          31  12290
# 167          2               134      toyota  ...       24          30   8449
# 21           1               118       dodge  ...       37          41   5572
# 55           3               150       mazda  ...       17          23  10945
# 60           0               115       mazda  ...       26          32   8495
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
for column in df.columns:
    print(column,df[column].eq(other="?").sum())
# Out:
# symboling 0
# normalized-losses 41
# make 0
# fuel-type 0
# aspiration 0
# num-of-doors 2
# body-style 0
# drive-wheels 0
# engine-location 0
# wheel-base 0
# length 0
# width 0
# height 0
# curb-weight 0
# engine-type 0
# num-of-cylinders 0
# engine-size 0
# fuel-system 0
# bore 4
# stroke 4
# compression-ratio 0
# horsepower 2
# peak-rpm 2
# city-mpg 0
# highway-mpg 0
# price 4

# %%
report = ProfileReport(df=df, title="car_profile", explorative=True)
report.to_file("/profiling/car_profile.html")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df = df.replace("?", np.nan)
df.sample(10)
# Out:
#      symboling normalized-losses        make  ... city-mpg highway-mpg  price
# 188          2                94  volkswagen  ...       26          32   9995
# 199         -1                74       volvo  ...       17          22  18950
# 65           0               118       mazda  ...       19          27  18280
# 66           0               NaN       mazda  ...       31          39  18344
# 7            1               NaN        audi  ...       19          25  18920
# 177         -1                65      toyota  ...       27          32  11248
# 154          0                81      toyota  ...       27          32   7898
# 91           1               128      nissan  ...       31          37   6649
# 158          0                91      toyota  ...       34          36   7898
# 189          3               NaN  volkswagen  ...       24          29  11595
#
# [10 rows x 26 columns]

# %%
df.isna().sum().sum()
# Out:
# np.int64(59)

# %% [markdown]
# # Identify Missing Values

# %%
df.isnull().any().any()
# Out:
# np.True_

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# <h3 id="deal_missing_values">Deal with missing data</h3>
# <b>How to deal with missing data?</b>
#
# <ol>
#     <li>drop data<br>
#         a. drop the whole row<br>
#         b. drop the whole column
#     </li>
#     <li>replace data<br>
#         a. replace it by mean<br>
#         b. replace it by frequency<br>
#         c. replace it based on other functions
#     </li>
# </ol>

# %% [markdown]
# Whole columns should be dropped only if most entries in the column are empty. In our dataset, none of the columns are empty enough to drop entirely.
# We have some freedom in choosing which method to replace data; however, some methods may seem more reasonable than others. We will apply each method to many different columns:
#
# <b>Replace by mean:</b>
# <ul>
#     <li>"normalized-losses": 41 missing data, replace them with mean</li>
#     <li>"stroke": 4 missing data, replace them with mean</li>
#     <li>"bore": 4 missing data, replace them with mean</li>
#     <li>"horsepower": 2 missing data, replace them with mean</li>
#     <li>"peak-rpm": 2 missing data, replace them with mean</li>
# </ul>
#
# <b>Replace by frequency:</b>
# <ul>
#     <li>"num-of-doors": 2 missing data, replace them with "four".
#         <ul>
#             <li>Reason: 84% sedans is four doors. Since four doors is most frequent, it is most likely to occur</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h4>Calculate the average of the column </h4>

# %%
avg_norml_loss = df["normalized-losses"].astype("float").mean()
avg_norml_loss
# Out:
# np.float64(122.0)

# %% [markdown]
# <h4>Replace "NaN" by mean value in "normalized-losses" column</h4>

# %%
df["normalized-losses"] = df["normalized-losses"].replace(np.nan, avg_norml_loss)
df["normalized-losses"]
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3        164
# 4        164
#        ...
# 200       95
# 201       95
# 202       95
# 203       95
# 204       95
# Name: normalized-losses, Length: 205, dtype: object

# %% [markdown]
# <h4>Calculate the mean value for 'bore' column</h4>

# %%
avg_bore = df["bore"].astype("float").mean()
df['bore'] = df["bore"].replace(np.nan, avg_bore)

# %%
avg_stroke = df["stroke"].astype("float").mean(axis=0)
print("Average of stroke:", avg_stroke)

# replace NaN by mean value in "stroke" column
df["stroke"] = df["stroke"].replace(np.nan, avg_stroke)
df["stroke"]
# Out:
# Average of stroke: 3.255422885572139
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: object

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average horsepower:", avg_horsepower)
df['horsepower'] = df['horsepower'].replace(np.nan, avg_horsepower)
# Out:
# Average horsepower: 104.25615763546799

# %%
avg_peakrpm= df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)
df['peak-rpm'] = df['peak-rpm'].replace(np.nan, avg_peakrpm)
# Out:
# Average peak rpm: 5125.369458128079

# %% [markdown]
# To see which values are present in a particular column, we can use the ".value_counts()" method:

# %%
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    116
# two      89
# Name: count, dtype: int64

# %%
max_category = df["num-of-doors"].value_counts().idxmax()
max_category
# Out:
# 'four'

# %%
# replace the missing 'num-of-doors' values by the most frequent
df["num-of-doors"] = df["num-of-doors"].replace(np.nan, max_category)

# %% [markdown]
# <h4>Lets list the data types for each column</h4>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# <h4>Convert data types to proper format</h4>

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")
df.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg    price
# 0          3                122  alfa-romero  ...       21          27  13495.0
# 1          3                122  alfa-romero  ...       21          27  16500.0
# 2          1                122  alfa-romero  ...       19          26  16500.0
# 3          2                164         audi  ...       24          30  13950.0
# 4          2                164         audi  ...       18          22  17450.0
#
# [5 rows x 26 columns]
